# %% [markdown]
# # CIFAR-10 Data Exploration

# %%
import sys
sys.path.insert(0, "..")

from src.data import get_loaders, visualize_batch

# %% [markdown]
# ## Dataset sizes and batch statistics

# %%
train_loader, test_loader = get_loaders(data_root="../data")

print(f"Train samples : {len(train_loader.dataset):,}")
print(f"Test  samples : {len(test_loader.dataset):,}")

images, labels = next(iter(train_loader))
print(f"\nBatch shape   : {tuple(images.shape)}  (N, C, H, W)")
print(f"Label shape   : {tuple(labels.shape)}")
print(f"Pixel min     : {images.min():.4f}")
print(f"Pixel max     : {images.max():.4f}")
# Out:
# Train samples : 50,000
# Test  samples : 10,000
# /Users/aleksandarmihaylov/anaconda3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Batch shape   : (128, 3, 32, 32)  (N, C, H, W)
# Label shape   : (128,)
# Pixel min     : -2.4291
# Pixel max     : 2.7537

# %% [markdown]
# ## Sample batch visualisation

# %%
import os
from IPython.display import Image

save_path = "../outputs/sample_batch.png"
visualize_batch(train_loader, n=32, save_path=save_path)

assert os.path.isfile(save_path), f"PNG not found at {save_path}"
print(f"Saved → {save_path}")
Image(save_path)
# Out:
# Saved → ../outputs/sample_batch.png
